# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../../data/Sleep_Efficiency.csv')

# If alcohol > 0, then alcohol = 1
df['Alcohol consumption'] = (df['Alcohol consumption'] > 0).astype(int)

# Split the data into two groups
df1 = df[df['Alcohol consumption'] == 1]
df0 = df[df['Alcohol consumption'] == 0]

df1.head()
# Out:
#      ID  Age  Gender          Bedtime      Wakeup time  Sleep duration  \
# 3   288   40  Female   2021/1/6 21:30   2021/1/6 05:00             7.5
# 8   298   27  Female  2021/1/11 00:30  2021/1/11 08:30             8.0
# 9   429   23    Male  2021/1/11 01:00  2021/1/11 09:00             8.0
# 10   78   46    Male  2021/1/11 02:00  2021/1/11 11:00             9.0
# 11  166   48  Female  2021/1/11 22:00  2021/1/11 05:00             7.0
#
#     Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 3               0.52                    23                     25
# 8               0.86                    20                     65
# 9               0.63                    20                     35
# 10              0.70                    18                     70
# 11              0.91                    25                     55
#
#     Light sleep percentage  Awakenings  Caffeine consumption  \
# 3                       52         NaN                  75.0
# ...

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot([df0['Sleep efficiency'], df1['Sleep efficiency']])
 
# show plot
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot([df0['REM sleep percentage'], df1['REM sleep percentage']])
 
# show plot
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot([df0['Sleep duration'], df1['Sleep duration']])
 
# show plot
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot([df0['Deep sleep percentage'], df1['Deep sleep percentage']])
 
# show plot
plt.show()
